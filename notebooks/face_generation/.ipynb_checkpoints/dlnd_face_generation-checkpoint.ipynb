# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    real_input_placeholder = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='real_input')
    z_input_placeholder = tf.placeholder(tf.float32, (None, z_dim), name='z_input')
    learning_rate_placeholder = tf.placeholder(tf.float32, None, name='learning_rate')
    
    return real_input_placeholder, z_input_placeholder, learning_rate_placeholder

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 28x28x3

        # 14x14x64
        x1 = tf.layers.conv2d(
            inputs=images,
            filters=64,
            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02),
            kernel_size=[3, 3],
            strides=2,
            padding="same",
        )
        x1 = tf.maximum(0.2 * x1, x1) # leaky relu

        # 7x7x128
        x2 = tf.layers.conv2d(
            inputs=x1,
            filters=128,
            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02),
            kernel_size=[3, 3],
            strides=2,
            padding="same",
        )
        x2 = tf.layers.batch_normalization(x2, training=True)
        x2 = tf.maximum(0.2 * x2, x2) # leaky relu
        
        # 4x4x256
        x3 = tf.layers.conv2d(
            inputs=x2,
            filters=256,
            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02),
            kernel_size=[3, 3],
            strides=2,
            padding="same",
        )
        x3 = tf.layers.batch_normalization(x3, training=True)
        x3 = tf.maximum(0.2 * x3, x3) # leaky relu
   
        flat = tf.reshape(x3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    with tf.variable_scope('generator', reuse=(not is_train)):
        x1 = tf.layers.dense(z, 7*7*512)
        
        # reshape fully connected for convolution
        x1 = tf.reshape(x1, (-1, 7, 7, 512))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(0.2 * x1, x1) # leaky relu

        # 14x14x256
        x2 = tf.layers.conv2d_transpose(
            inputs=x1,
            filters=256,
            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02),
            kernel_size=[3, 3],
            strides=2,
            padding="same",
        )
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(0.2 * x2, x2) # leaky relu
        
        # 14x14x128
        x3 = tf.layers.conv2d_transpose(
            inputs=x2,
            filters=128,
            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02),
            kernel_size=[3, 3],
            strides=1,
            padding="same",
        )
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(0.2 * x3, x3) # leaky relu

        # 28x28xdim
        x4 = tf.layers.conv2d_transpose(
            inputs=x3,
            filters=out_channel_dim,
            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02),
            kernel_size=[3, 3],
            strides=2,
            padding="same",
        )

        return tf.tanh(x4)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    label_smoothing = 0.9
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real) * label_smoothing))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = (d_loss_real + d_loss_fake)

    return d_loss, g_loss

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Suggestion from here: http://ruishu.io/2016/12/27/batchnorm/
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    g_updates = [opt for opt in update_ops if opt.name.startswith('generator')]
    
    d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    with tf.control_dependencies(g_updates):
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    tf.reset_default_graph()
    _, image_width, image_height, image_channels = data_shape
    real_input_placeholder, z_input_placeholder, learning_rate_placeholder = model_inputs(image_width, image_height, image_channels, z_dim)
    d_loss, g_loss = model_loss(real_input_placeholder, z_input_placeholder, image_channels)
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_rate_placeholder, beta1)

    steps = 0 
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_train_opt, feed_dict={
                    real_input_placeholder: batch_images,
                    z_input_placeholder: batch_z,
                    learning_rate_placeholder: learning_rate
                })
                _ = sess.run(g_train_opt, feed_dict={
                    z_input_placeholder: batch_z,
                    learning_rate_placeholder: learning_rate
                })

                if steps % 10 == 0:
                    train_loss_d = d_loss.eval({
                        z_input_placeholder: batch_z, 
                        real_input_placeholder: batch_images
                    })
                    train_loss_g = g_loss.eval({
                        z_input_placeholder: batch_z
                    })

                    print("Epoch {}/{}...".format(epoch_i + 1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    
                if steps % 100 == 0:
                    show_generator_output(sess, 25, z_input_placeholder, image_channels, data_image_mode)
                
                steps += 1

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0008
beta1 = 0.7

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 6.4779... Generator Loss: 0.0043
# Epoch 1/2... Discriminator Loss: 0.4420... Generator Loss: 7.9607
# Epoch 1/2... Discriminator Loss: 0.4887... Generator Loss: 5.2634
# Epoch 1/2... Discriminator Loss: 0.5595... Generator Loss: 2.6993
# Epoch 1/2... Discriminator Loss: 0.5055... Generator Loss: 2.5138
# Epoch 1/2... Discriminator Loss: 2.3030... Generator Loss: 0.2262
# Epoch 1/2... Discriminator Loss: 0.6807... Generator Loss: 2.0164
# Epoch 1/2... Discriminator Loss: 0.7837... Generator Loss: 1.7592
# Epoch 1/2... Discriminator Loss: 0.7258... Generator Loss: 1.9290
# Epoch 1/2... Discriminator Loss: 0.8488... Generator Loss: 1.3054
# Epoch 1/2... Discriminator Loss: 0.3999... Generator Loss: 3.8679
# Epoch 1/2... Discriminator Loss: 0.4442... Generator Loss: 2.8101
# Epoch 1/2... Discriminator Loss: 0.6163... Generator Loss: 5.7035
# Epoch 1/2... Discriminator Loss: 1.2534... Generator Loss: 0.8115
# Epoch 1/2... Discriminator Loss: 0.6480... Generator Loss: 2.9474
# Epoch 1/2... Discriminator Loss: 0.6004... Generator Loss: 2.1886
# Epoch 1/2... Discriminator Loss: 0.6516... Generator Loss: 1.6574
# Epoch 1/2... Discriminator Loss: 0.7101... Generator Loss: 1.4097
# Epoch 1/2... Discriminator Loss: 0.5118... Generator Loss: 2.2394
# Epoch 1/2... Discriminator Loss: 0.6869... Generator Loss: 2.2737
# Epoch 1/2... Discriminator Loss: 0.5798... Generator Loss: 2.5621
# Epoch 1/2... Discriminator Loss: 0.5393... Generator Loss: 2.3918
# Epoch 1/2... Discriminator Loss: 0.5528... Generator Loss: 2.2262
# Epoch 1/2... Discriminator Loss: 0.5932... Generator Loss: 2.5289
# Epoch 1/2... Discriminator Loss: 0.8263... Generator Loss: 1.1317
# Epoch 1/2... Discriminator Loss: 0.5675... Generator Loss: 2.3469
# Epoch 1/2... Discriminator Loss: 0.5214... Generator Loss: 2.3858
# Epoch 1/2... Discriminator Loss: 0.6340... Generator Loss: 3.3161
# Epoch 1/2... Discriminator Loss: 0.5555... Generator Loss: 2.1883
# Epoch 1/2... Discriminator Loss: 2.5073... Generator Loss: 0.2104
# Epoch 1/2... Discriminator Loss: 0.7837... Generator Loss: 1.4317
# Epoch 1/2... Discriminator Loss: 0.5892... Generator Loss: 2.2759
# Epoch 1/2... Discriminator Loss: 0.5060... Generator Loss: 2.5742
# Epoch 1/2... Discriminator Loss: 0.4798... Generator Loss: 2.4836
# Epoch 1/2... Discriminator Loss: 0.4678... Generator Loss: 2.5338
# Epoch 1/2... Discriminator Loss: 0.4483... Generator Loss: 2.8730
# Epoch 1/2... Discriminator Loss: 5.9992... Generator Loss: 7.4814
# Epoch 1/2... Discriminator Loss: 0.7705... Generator Loss: 1.3840
# Epoch 1/2... Discriminator Loss: 0.4636... Generator Loss: 2.6854
# Epoch 1/2... Discriminator Loss: 0.4792... Generator Loss: 2.5598
# Epoch 1/2... Discriminator Loss: 0.4385... Generator Loss: 2.8936
# Epoch 1/2... Discriminator Loss: 0.4392... Generator Loss: 2.7018
# Epoch 1/2... Discriminator Loss: 0.4416... Generator Loss: 2.6630
# Epoch 1/2... Discriminator Loss: 0.4325... Generator Loss: 2.9805
# Epoch 1/2... Discriminator Loss: 0.4922... Generator Loss: 2.2198
# Epoch 1/2... Discriminator Loss: 0.4247... Generator Loss: 2.8750
# Epoch 1/2... Discriminator Loss: 1.0664... Generator Loss: 3.5057
# Epoch 2/2... Discriminator Loss: 0.4783... Generator Loss: 2.5829
# Epoch 2/2... Discriminator Loss: 0.5815... Generator Loss: 1.8762
# Epoch 2/2... Discriminator Loss: 0.5012... Generator Loss: 2.2786
# Epoch 2/2... Discriminator Loss: 0.4253... Generator Loss: 2.9759
# Epoch 2/2... Discriminator Loss: 0.4580... Generator Loss: 2.6669
# Epoch 2/2... Discriminator Loss: 0.4773... Generator Loss: 2.2515
# Epoch 2/2... Discriminator Loss: 0.4672... Generator Loss: 2.5494
# Epoch 2/2... Discriminator Loss: 0.4233... Generator Loss: 2.8565
# Epoch 2/2... Discriminator Loss: 0.5149... Generator Loss: 7.3461
# Epoch 2/2... Discriminator Loss: 0.5719... Generator Loss: 2.4895
# Epoch 2/2... Discriminator Loss: 0.6674... Generator Loss: 1.5045
# Epoch 2/2... Discriminator Loss: 0.4865... Generator Loss: 2.5091
# Epoch 2/2... Discriminator Loss: 0.6291... Generator Loss: 2.2566
# Epoch 2/2... Discriminator Loss: 0.5197... Generator Loss: 2.8394
# Epoch 2/2... Discriminator Loss: 0.4702... Generator Loss: 2.4449
# Epoch 2/2... Discriminator Loss: 0.4658... Generator Loss: 2.4400
# Epoch 2/2... Discriminator Loss: 0.4810... Generator Loss: 2.1982
# Epoch 2/2... Discriminator Loss: 0.4315... Generator Loss: 2.7111
# Epoch 2/2... Discriminator Loss: 0.4428... Generator Loss: 3.2936
# Epoch 2/2... Discriminator Loss: 2.0965... Generator Loss: 0.2999
# Epoch 2/2... Discriminator Loss: 0.7835... Generator Loss: 1.5647
# Epoch 2/2... Discriminator Loss: 0.6375... Generator Loss: 1.6394
# Epoch 2/2... Discriminator Loss: 0.6488... Generator Loss: 1.7036
# Epoch 2/2... Discriminator Loss: 0.5385... Generator Loss: 2.3032
# Epoch 2/2... Discriminator Loss: 0.4815... Generator Loss: 3.4146
# Epoch 2/2... Discriminator Loss: 0.5890... Generator Loss: 1.7772
# Epoch 2/2... Discriminator Loss: 0.6641... Generator Loss: 1.3901
# Epoch 2/2... Discriminator Loss: 0.5305... Generator Loss: 2.8710
# Epoch 2/2... Discriminator Loss: 0.6940... Generator Loss: 1.4513
# Epoch 2/2... Discriminator Loss: 0.5373... Generator Loss: 1.8738
# Epoch 2/2... Discriminator Loss: 0.5115... Generator Loss: 2.2055
# Epoch 2/2... Discriminator Loss: 0.7886... Generator Loss: 1.6391
# Epoch 2/2... Discriminator Loss: 0.4558... Generator Loss: 2.9961
# Epoch 2/2... Discriminator Loss: 0.6049... Generator Loss: 1.8887
# Epoch 2/2... Discriminator Loss: 0.4353... Generator Loss: 2.6884
# Epoch 2/2... Discriminator Loss: 0.4439... Generator Loss: 2.4661
# Epoch 2/2... Discriminator Loss: 0.4557... Generator Loss: 2.4343
# Epoch 2/2... Discriminator Loss: 6.1109... Generator Loss: 8.5948
# Epoch 2/2... Discriminator Loss: 0.7229... Generator Loss: 1.5303
# Epoch 2/2... Discriminator Loss: 0.6310... Generator Loss: 1.6267
# Epoch 2/2... Discriminator Loss: 0.7882... Generator Loss: 1.7124
# Epoch 2/2... Discriminator Loss: 0.6260... Generator Loss: 1.9039
# Epoch 2/2... Discriminator Loss: 0.7945... Generator Loss: 2.4592
# Epoch 2/2... Discriminator Loss: 0.6629... Generator Loss: 1.5295
# Epoch 2/2... Discriminator Loss: 0.4263... Generator Loss: 2.9526
# Epoch 2/2... Discriminator Loss: 0.8344... Generator Loss: 2.9127
# Epoch 2/2... Discriminator Loss: 1.0482... Generator Loss: 0.7880
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-9246b051b37d> in <module>()
#      12 with tf.Graph().as_default():
#      13     train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
# ---> 14           mnist_dataset.shape, mnist_dataset.image_mode)
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      64         if type is None:
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#      68                 return
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3626     finally:
#    3627       if self._enforce_nesting:
# -> 3628         if self.stack[-1] is not default:
#    3629           raise AssertionError(
#    3630               "Nesting violated for default stack of %s objects"
#
# IndexError: list index out of range

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0008
beta1 = 0.7

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 6.1941... Generator Loss: 0.0062
# Epoch 1/1... Discriminator Loss: 0.5505... Generator Loss: 4.3935
# Epoch 1/1... Discriminator Loss: 1.5046... Generator Loss: 0.6371
# Epoch 1/1... Discriminator Loss: 0.6391... Generator Loss: 2.3111
# Epoch 1/1... Discriminator Loss: 0.7778... Generator Loss: 1.4876
# Epoch 1/1... Discriminator Loss: 0.4551... Generator Loss: 4.4869
# Epoch 1/1... Discriminator Loss: 0.5858... Generator Loss: 2.2383
# Epoch 1/1... Discriminator Loss: 1.0877... Generator Loss: 0.8523
# Epoch 1/1... Discriminator Loss: 1.0963... Generator Loss: 1.2891
# Epoch 1/1... Discriminator Loss: 0.7982... Generator Loss: 1.4704
# Epoch 1/1... Discriminator Loss: 0.5964... Generator Loss: 2.2129
# Epoch 1/1... Discriminator Loss: 1.1751... Generator Loss: 0.7877
# Epoch 1/1... Discriminator Loss: 1.4927... Generator Loss: 0.4731
# Epoch 1/1... Discriminator Loss: 0.8238... Generator Loss: 1.7101
# Epoch 1/1... Discriminator Loss: 2.0112... Generator Loss: 3.5301
# Epoch 1/1... Discriminator Loss: 0.7074... Generator Loss: 1.7715
# Epoch 1/1... Discriminator Loss: 0.5341... Generator Loss: 3.0976
# Epoch 1/1... Discriminator Loss: 1.0015... Generator Loss: 1.8753
# Epoch 1/1... Discriminator Loss: 0.9626... Generator Loss: 1.5569
# Epoch 1/1... Discriminator Loss: 0.9929... Generator Loss: 1.1455
# Epoch 1/1... Discriminator Loss: 0.9970... Generator Loss: 1.8385
# Epoch 1/1... Discriminator Loss: 0.9043... Generator Loss: 1.4640
# Epoch 1/1... Discriminator Loss: 1.4622... Generator Loss: 0.5585
# Epoch 1/1... Discriminator Loss: 1.6068... Generator Loss: 0.4729
# Epoch 1/1... Discriminator Loss: 0.8005... Generator Loss: 1.7831
# Epoch 1/1... Discriminator Loss: 1.1200... Generator Loss: 2.6561
# Epoch 1/1... Discriminator Loss: 0.6732... Generator Loss: 1.9947
# Epoch 1/1... Discriminator Loss: 0.7387... Generator Loss: 2.1907
# Epoch 1/1... Discriminator Loss: 0.9489... Generator Loss: 2.1430
# Epoch 1/1... Discriminator Loss: 1.0687... Generator Loss: 2.3259
# Epoch 1/1... Discriminator Loss: 1.3530... Generator Loss: 0.7855
# Epoch 1/1... Discriminator Loss: 0.6511... Generator Loss: 3.1412
# Epoch 1/1... Discriminator Loss: 1.0698... Generator Loss: 2.7816
# Epoch 1/1... Discriminator Loss: 1.3757... Generator Loss: 0.5672
# Epoch 1/1... Discriminator Loss: 0.6690... Generator Loss: 2.1477
# Epoch 1/1... Discriminator Loss: 0.7507... Generator Loss: 1.7873
# Epoch 1/1... Discriminator Loss: 0.8295... Generator Loss: 3.0895
# Epoch 1/1... Discriminator Loss: 0.7419... Generator Loss: 1.6883
# Epoch 1/1... Discriminator Loss: 0.5166... Generator Loss: 5.6593
# Epoch 1/1... Discriminator Loss: 0.8848... Generator Loss: 3.2337
# Epoch 1/1... Discriminator Loss: 0.7228... Generator Loss: 6.0497
# Epoch 1/1... Discriminator Loss: 0.4309... Generator Loss: 5.3145
# Epoch 1/1... Discriminator Loss: 0.9715... Generator Loss: 5.1990
# Epoch 1/1... Discriminator Loss: 0.9730... Generator Loss: 4.3968
# Epoch 1/1... Discriminator Loss: 0.9983... Generator Loss: 1.6378
# Epoch 1/1... Discriminator Loss: 3.4410... Generator Loss: 3.6796
# Epoch 1/1... Discriminator Loss: 1.4316... Generator Loss: 0.6317
# Epoch 1/1... Discriminator Loss: 0.8025... Generator Loss: 2.0058
# Epoch 1/1... Discriminator Loss: 1.0853... Generator Loss: 3.3544
# Epoch 1/1... Discriminator Loss: 1.0648... Generator Loss: 1.3551
# Epoch 1/1... Discriminator Loss: 0.8562... Generator Loss: 1.4573
# Epoch 1/1... Discriminator Loss: 0.9944... Generator Loss: 2.1165
# Epoch 1/1... Discriminator Loss: 0.9971... Generator Loss: 1.1435
# Epoch 1/1... Discriminator Loss: 0.8110... Generator Loss: 1.7777
# Epoch 1/1... Discriminator Loss: 0.9369... Generator Loss: 2.1640
# Epoch 1/1... Discriminator Loss: 0.6111... Generator Loss: 1.9608
# Epoch 1/1... Discriminator Loss: 0.8087... Generator Loss: 2.1348
# Epoch 1/1... Discriminator Loss: 0.8703... Generator Loss: 1.2205
# Epoch 1/1... Discriminator Loss: 0.9868... Generator Loss: 1.2285
# Epoch 1/1... Discriminator Loss: 0.9790... Generator Loss: 1.8463
# Epoch 1/1... Discriminator Loss: 0.8307... Generator Loss: 1.6515
# Epoch 1/1... Discriminator Loss: 1.6333... Generator Loss: 3.8929
# Epoch 1/1... Discriminator Loss: 0.8525... Generator Loss: 2.4332
# Epoch 1/1... Discriminator Loss: 0.8436... Generator Loss: 1.5591
# Epoch 1/1... Discriminator Loss: 0.9103... Generator Loss: 1.5902
# Epoch 1/1... Discriminator Loss: 0.8188... Generator Loss: 1.8433
# Epoch 1/1... Discriminator Loss: 0.8497... Generator Loss: 2.4648
# Epoch 1/1... Discriminator Loss: 0.8832... Generator Loss: 1.8376
# Epoch 1/1... Discriminator Loss: 0.7988... Generator Loss: 2.3596
# Epoch 1/1... Discriminator Loss: 0.8517... Generator Loss: 1.4111
# Epoch 1/1... Discriminator Loss: 1.0360... Generator Loss: 1.0878
# Epoch 1/1... Discriminator Loss: 0.8716... Generator Loss: 1.8747
# Epoch 1/1... Discriminator Loss: 0.9893... Generator Loss: 1.4139
# Epoch 1/1... Discriminator Loss: 0.9122... Generator Loss: 1.1641
# Epoch 1/1... Discriminator Loss: 0.9276... Generator Loss: 2.8935
# Epoch 1/1... Discriminator Loss: 0.9503... Generator Loss: 1.7250
# Epoch 1/1... Discriminator Loss: 0.6468... Generator Loss: 3.1479
# Epoch 1/1... Discriminator Loss: 0.7603... Generator Loss: 1.6248
# Epoch 1/1... Discriminator Loss: 1.0254... Generator Loss: 1.0369
# Epoch 1/1... Discriminator Loss: 0.9102... Generator Loss: 1.9788
# Epoch 1/1... Discriminator Loss: 1.2517... Generator Loss: 0.9191
# Epoch 1/1... Discriminator Loss: 1.1626... Generator Loss: 2.2324
# Epoch 1/1... Discriminator Loss: 0.7598... Generator Loss: 1.5002
# Epoch 1/1... Discriminator Loss: 1.0539... Generator Loss: 2.7698
# Epoch 1/1... Discriminator Loss: 2.0279... Generator Loss: 5.2931
# Epoch 1/1... Discriminator Loss: 1.1453... Generator Loss: 0.7727
# Epoch 1/1... Discriminator Loss: 0.9066... Generator Loss: 1.6544
# Epoch 1/1... Discriminator Loss: 0.9841... Generator Loss: 1.6010
# Epoch 1/1... Discriminator Loss: 1.1413... Generator Loss: 2.5158
# Epoch 1/1... Discriminator Loss: 0.9046... Generator Loss: 1.9040
# Epoch 1/1... Discriminator Loss: 0.8186... Generator Loss: 2.7200
# Epoch 1/1... Discriminator Loss: 1.0764... Generator Loss: 2.3316
# Epoch 1/1... Discriminator Loss: 0.6628... Generator Loss: 1.9162
# Epoch 1/1... Discriminator Loss: 1.1278... Generator Loss: 1.3548
# Epoch 1/1... Discriminator Loss: 1.1416... Generator Loss: 0.8723
# Epoch 1/1... Discriminator Loss: 0.7824... Generator Loss: 1.4097
# Epoch 1/1... Discriminator Loss: 1.1505... Generator Loss: 0.7675
# Epoch 1/1... Discriminator Loss: 0.7442... Generator Loss: 1.8753
# Epoch 1/1... Discriminator Loss: 0.8062... Generator Loss: 1.4594
# Epoch 1/1... Discriminator Loss: 1.5204... Generator Loss: 3.1941
# Epoch 1/1... Discriminator Loss: 0.8091... Generator Loss: 1.4772
# Epoch 1/1... Discriminator Loss: 1.1571... Generator Loss: 0.9053
# Epoch 1/1... Discriminator Loss: 0.6622... Generator Loss: 1.8213
# Epoch 1/1... Discriminator Loss: 0.6197... Generator Loss: 2.7343
# Epoch 1/1... Discriminator Loss: 1.2330... Generator Loss: 1.1913
# Epoch 1/1... Discriminator Loss: 2.2207... Generator Loss: 3.4233
# Epoch 1/1... Discriminator Loss: 0.8662... Generator Loss: 1.5191
# Epoch 1/1... Discriminator Loss: 0.7809... Generator Loss: 2.3422
# Epoch 1/1... Discriminator Loss: 1.0885... Generator Loss: 0.8391
# Epoch 1/1... Discriminator Loss: 0.7613... Generator Loss: 2.1659
# Epoch 1/1... Discriminator Loss: 0.7947... Generator Loss: 3.4753
# Epoch 1/1... Discriminator Loss: 1.3990... Generator Loss: 0.5210
# Epoch 1/1... Discriminator Loss: 0.7086... Generator Loss: 2.2946
# Epoch 1/1... Discriminator Loss: 0.9546... Generator Loss: 1.1912
# Epoch 1/1... Discriminator Loss: 0.7051... Generator Loss: 1.6518
# Epoch 1/1... Discriminator Loss: 0.6501... Generator Loss: 2.1654
# Epoch 1/1... Discriminator Loss: 0.9357... Generator Loss: 2.0252
# Epoch 1/1... Discriminator Loss: 1.1153... Generator Loss: 2.7321
# Epoch 1/1... Discriminator Loss: 0.8397... Generator Loss: 1.3232
# Epoch 1/1... Discriminator Loss: 0.7496... Generator Loss: 1.4519
# Epoch 1/1... Discriminator Loss: 1.0156... Generator Loss: 1.7633
# Epoch 1/1... Discriminator Loss: 0.8930... Generator Loss: 1.3387
# Epoch 1/1... Discriminator Loss: 1.0921... Generator Loss: 1.6326
# Epoch 1/1... Discriminator Loss: 1.7020... Generator Loss: 2.5506
# Epoch 1/1... Discriminator Loss: 0.6391... Generator Loss: 2.1517
# Epoch 1/1... Discriminator Loss: 1.0967... Generator Loss: 1.5095
# Epoch 1/1... Discriminator Loss: 0.9637... Generator Loss: 1.0338
# Epoch 1/1... Discriminator Loss: 1.1959... Generator Loss: 1.2645
# Epoch 1/1... Discriminator Loss: 0.7790... Generator Loss: 2.5981
# Epoch 1/1... Discriminator Loss: 0.7167... Generator Loss: 1.6972
# Epoch 1/1... Discriminator Loss: 0.9847... Generator Loss: 0.8711
# Epoch 1/1... Discriminator Loss: 1.0014... Generator Loss: 1.5761
# Epoch 1/1... Discriminator Loss: 0.6512... Generator Loss: 1.8983
# Epoch 1/1... Discriminator Loss: 1.0617... Generator Loss: 0.9097
# Epoch 1/1... Discriminator Loss: 1.0998... Generator Loss: 0.9396
# Epoch 1/1... Discriminator Loss: 0.8682... Generator Loss: 1.6005
# Epoch 1/1... Discriminator Loss: 1.3617... Generator Loss: 2.3732
# Epoch 1/1... Discriminator Loss: 1.3134... Generator Loss: 2.3999
# Epoch 1/1... Discriminator Loss: 0.8516... Generator Loss: 1.7047
# Epoch 1/1... Discriminator Loss: 1.1650... Generator Loss: 1.7160
# Epoch 1/1... Discriminator Loss: 0.7978... Generator Loss: 1.5212
# Epoch 1/1... Discriminator Loss: 1.0578... Generator Loss: 1.8773
# Epoch 1/1... Discriminator Loss: 0.9530... Generator Loss: 1.5272
# Epoch 1/1... Discriminator Loss: 0.9736... Generator Loss: 1.5224
# Epoch 1/1... Discriminator Loss: 0.8094... Generator Loss: 1.4923
# Epoch 1/1... Discriminator Loss: 1.2459... Generator Loss: 1.0125
# Epoch 1/1... Discriminator Loss: 0.7485... Generator Loss: 1.8880
# Epoch 1/1... Discriminator Loss: 0.6893... Generator Loss: 1.5724
# Epoch 1/1... Discriminator Loss: 0.7749... Generator Loss: 1.3231
# Epoch 1/1... Discriminator Loss: 0.7837... Generator Loss: 1.7026
# Epoch 1/1... Discriminator Loss: 0.7151... Generator Loss: 1.7450
# Epoch 1/1... Discriminator Loss: 1.0759... Generator Loss: 2.5130
# Epoch 1/1... Discriminator Loss: 1.0175... Generator Loss: 0.9892
# Epoch 1/1... Discriminator Loss: 1.0362... Generator Loss: 1.8522
# Epoch 1/1... Discriminator Loss: 1.1985... Generator Loss: 1.9351
# Epoch 1/1... Discriminator Loss: 0.8565... Generator Loss: 1.3081
# Epoch 1/1... Discriminator Loss: 0.9250... Generator Loss: 2.9815
# Epoch 1/1... Discriminator Loss: 1.0396... Generator Loss: 0.9428
# Epoch 1/1... Discriminator Loss: 1.1003... Generator Loss: 1.6399
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-1579c9c39442> in <module>()
#      12 with tf.Graph().as_default():
#      13     train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
# ---> 14           celeba_dataset.shape, celeba_dataset.image_mode)
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      64         if type is None:
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#      68                 return
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3626     finally:
#    3627       if self._enforce_nesting:
# -> 3628         if self.stack[-1] is not default:
#    3629           raise AssertionError(
#    3630               "Nesting violated for default stack of %s objects"
#
# IndexError: list index out of range

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
