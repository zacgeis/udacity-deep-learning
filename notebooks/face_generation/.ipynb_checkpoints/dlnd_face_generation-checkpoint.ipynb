# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    real_input_placeholder = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='real_input')
    z_input_placeholder = tf.placeholder(tf.float32, (None, z_dim), name='z_input')
    learning_rate_placeholder = tf.placeholder(tf.float32, None, name='learning_rate')
    
    return real_input_placeholder, z_input_placeholder, learning_rate_placeholder

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 28x28x3

        # 14x14x64
        x1 = tf.layers.conv2d(
            inputs=images,
            filters=64,
            kernel_size=[5, 5],
            strides=2,
            padding="same",
        )
        x1 = tf.maximum(0.2 * x1, x1) # leaky relu

        # 7x7x128
        x2 = tf.layers.conv2d(
            inputs=x1,
            filters=128,
            kernel_size=[5, 5],
            strides=2,
            padding="same",
        )
        x2 = tf.layers.batch_normalization(x2, training=True)
        x2 = tf.maximum(0.2 * x2, x2) # leaky relu
        
        # 2x2x256
        x3 = tf.layers.conv2d(
            inputs=x2,
            filters=256,
            kernel_size=[5, 5],
            strides=2,
            padding="valid",
        )
        x3 = tf.layers.batch_normalization(x3, training=True)
        x3 = tf.maximum(0.2 * x3, x3) # leaky relu
   
        flat = tf.reshape(x3, (-1, 2*2*512))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    with tf.variable_scope('generator', reuse=(not is_train)):
        x1 = tf.layers.dense(z, 2*2*512)
        
        # reshape fully connected for convolution
        x1 = tf.reshape(x1, (-1, 2, 2, 512))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(0.2 * x1, x1) # leaky relu

        # 7x7x512
        x2 = tf.layers.conv2d_transpose(
            inputs=x1,
            filters=256,
            kernel_size=[5, 5],
            strides=2,
            padding="valid",
        )
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(0.2 * x2, x2) # leaky relu

        # 14x14x128
        x3 = tf.layers.conv2d_transpose(
            inputs=x2,
            filters=128,
            kernel_size=[2, 2],
            strides=2,
            padding="same",
        )
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(0.2 * x3, x3) # leaky relu
        
        # 28x28xdim
        x4 = tf.layers.conv2d_transpose(
            inputs=x3,
            filters=out_channel_dim,
            kernel_size=[5, 5],
            strides=2,
            padding="same",
        )

        return tf.tanh(x4)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    tf.reset_default_graph()
    _, image_width, image_height, image_channels = data_shape
    real_input_placeholder, z_input_placeholder, learning_rate_placeholder = model_inputs(image_width, image_height, image_channels, z_dim)
    d_loss, g_loss = model_loss(real_input_placeholder, z_input_placeholder, image_channels)
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_rate_placeholder, beta1)

    steps = 0 
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                steps += 1

                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_train_opt, feed_dict={
                    real_input_placeholder: batch_images,
                    z_input_placeholder: batch_z,
                    learning_rate_placeholder: learning_rate
                })
                _ = sess.run(g_train_opt, feed_dict={
                    z_input_placeholder: batch_z,
                    learning_rate_placeholder: learning_rate
                })
                _ = sess.run(g_train_opt, feed_dict={
                    z_input_placeholder: batch_z,
                    learning_rate_placeholder: learning_rate
                })
                _ = sess.run(g_train_opt, feed_dict={
                    z_input_placeholder: batch_z,
                    learning_rate_placeholder: learning_rate
                })

                if steps % 10 == 0:
                    train_loss_d = d_loss.eval({
                        z_input_placeholder: batch_z, 
                        real_input_placeholder: batch_images
                    })
                    train_loss_g = g_loss.eval({
                        z_input_placeholder: batch_z
                    })

                    print("Epoch {}/{}...".format(epoch_i + 1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    
                if steps % 200 == 0:
                    show_generator_output(sess, 25, z_input_placeholder, image_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 5.1879... Generator Loss: 0.0087
# Epoch 1/2... Discriminator Loss: 3.7370... Generator Loss: 0.0545
# Epoch 1/2... Discriminator Loss: 2.7160... Generator Loss: 0.2135
# Epoch 1/2... Discriminator Loss: 2.0430... Generator Loss: 0.4695
# Epoch 1/2... Discriminator Loss: 1.3664... Generator Loss: 0.7038
# Epoch 1/2... Discriminator Loss: 1.2665... Generator Loss: 0.7878
# Epoch 1/2... Discriminator Loss: 2.0224... Generator Loss: 0.3454
# Epoch 1/2... Discriminator Loss: 1.6472... Generator Loss: 0.5840
# Epoch 1/2... Discriminator Loss: 1.7197... Generator Loss: 0.4729
# Epoch 1/2... Discriminator Loss: 1.6028... Generator Loss: 0.6127
# Epoch 1/2... Discriminator Loss: 1.3976... Generator Loss: 0.7732
# Epoch 1/2... Discriminator Loss: 1.4680... Generator Loss: 0.6157
# Epoch 1/2... Discriminator Loss: 1.4398... Generator Loss: 0.6389
# Epoch 1/2... Discriminator Loss: 1.3882... Generator Loss: 0.6624
# Epoch 1/2... Discriminator Loss: 1.4059... Generator Loss: 0.5944
# Epoch 1/2... Discriminator Loss: 1.4539... Generator Loss: 0.5890
# Epoch 1/2... Discriminator Loss: 1.1889... Generator Loss: 0.7828
# Epoch 1/2... Discriminator Loss: 1.2200... Generator Loss: 0.7244
# Epoch 1/2... Discriminator Loss: 1.3509... Generator Loss: 0.6131
# Epoch 1/2... Discriminator Loss: 1.9919... Generator Loss: 0.3297
# Epoch 1/2... Discriminator Loss: 2.3895... Generator Loss: 0.2551
# Epoch 1/2... Discriminator Loss: 1.8960... Generator Loss: 0.4759
# Epoch 1/2... Discriminator Loss: 1.3346... Generator Loss: 0.7426
# Epoch 1/2... Discriminator Loss: 1.2910... Generator Loss: 0.7130
# Epoch 1/2... Discriminator Loss: 1.1330... Generator Loss: 0.8877
# Epoch 1/2... Discriminator Loss: 1.2351... Generator Loss: 0.7828
# Epoch 1/2... Discriminator Loss: 1.2017... Generator Loss: 0.6879
# Epoch 1/2... Discriminator Loss: 1.1953... Generator Loss: 0.7073
# Epoch 1/2... Discriminator Loss: 1.1850... Generator Loss: 0.9812
# Epoch 1/2... Discriminator Loss: 1.2792... Generator Loss: 0.4957
# Epoch 1/2... Discriminator Loss: 1.0284... Generator Loss: 0.8539
# Epoch 1/2... Discriminator Loss: 1.2052... Generator Loss: 0.5280
# Epoch 1/2... Discriminator Loss: 1.1367... Generator Loss: 1.3160
# Epoch 1/2... Discriminator Loss: 1.0959... Generator Loss: 0.8651
# Epoch 1/2... Discriminator Loss: 1.1129... Generator Loss: 0.8374
# Epoch 1/2... Discriminator Loss: 1.1541... Generator Loss: 0.6658
# Epoch 1/2... Discriminator Loss: 1.3123... Generator Loss: 0.4317
# Epoch 1/2... Discriminator Loss: 1.0721... Generator Loss: 1.2572
# Epoch 1/2... Discriminator Loss: 1.1625... Generator Loss: 0.5895
# Epoch 1/2... Discriminator Loss: 1.2821... Generator Loss: 0.4621
# Epoch 1/2... Discriminator Loss: 1.1146... Generator Loss: 0.6876
# Epoch 1/2... Discriminator Loss: 1.0000... Generator Loss: 0.7735
# Epoch 1/2... Discriminator Loss: 1.1439... Generator Loss: 0.4956
# Epoch 1/2... Discriminator Loss: 0.8335... Generator Loss: 2.0573
# Epoch 1/2... Discriminator Loss: 0.7755... Generator Loss: 1.4966
# Epoch 1/2... Discriminator Loss: 0.7800... Generator Loss: 1.1608
# Epoch 2/2... Discriminator Loss: 1.0088... Generator Loss: 0.7803
# Epoch 2/2... Discriminator Loss: 0.9763... Generator Loss: 0.6352
# Epoch 2/2... Discriminator Loss: 0.8422... Generator Loss: 0.8185
# Epoch 2/2... Discriminator Loss: 0.3909... Generator Loss: 2.6259
# Epoch 2/2... Discriminator Loss: 0.3796... Generator Loss: 2.0921
# Epoch 2/2... Discriminator Loss: 0.5574... Generator Loss: 1.7004
# Epoch 2/2... Discriminator Loss: 0.4435... Generator Loss: 2.0259
# Epoch 2/2... Discriminator Loss: 2.1495... Generator Loss: 0.7845
# Epoch 2/2... Discriminator Loss: 0.7972... Generator Loss: 0.9168
# Epoch 2/2... Discriminator Loss: 0.6097... Generator Loss: 1.3136
# Epoch 2/2... Discriminator Loss: 0.5112... Generator Loss: 1.4509
# Epoch 2/2... Discriminator Loss: 0.4693... Generator Loss: 1.3291
# Epoch 2/2... Discriminator Loss: 1.3461... Generator Loss: 0.3984
# Epoch 2/2... Discriminator Loss: 0.3239... Generator Loss: 1.9176
# Epoch 2/2... Discriminator Loss: 0.4018... Generator Loss: 1.5789
# Epoch 2/2... Discriminator Loss: 1.2841... Generator Loss: 0.3652
# Epoch 2/2... Discriminator Loss: 2.0882... Generator Loss: 0.3831
# Epoch 2/2... Discriminator Loss: 0.4303... Generator Loss: 2.3436
# Epoch 2/2... Discriminator Loss: 0.4355... Generator Loss: 1.5989
# Epoch 2/2... Discriminator Loss: 0.3360... Generator Loss: 2.5150
# Epoch 2/2... Discriminator Loss: 0.3791... Generator Loss: 1.6288
# Epoch 2/2... Discriminator Loss: 0.2455... Generator Loss: 1.9612
# Epoch 2/2... Discriminator Loss: 0.2656... Generator Loss: 2.1215
# Epoch 2/2... Discriminator Loss: 0.4637... Generator Loss: 1.2637
# Epoch 2/2... Discriminator Loss: 0.3033... Generator Loss: 1.9483
# Epoch 2/2... Discriminator Loss: 0.1995... Generator Loss: 2.7892
# Epoch 2/2... Discriminator Loss: 1.7191... Generator Loss: 0.2659
# Epoch 2/2... Discriminator Loss: 0.5048... Generator Loss: 1.2802
# Epoch 2/2... Discriminator Loss: 0.4867... Generator Loss: 1.3378
# Epoch 2/2... Discriminator Loss: 0.4251... Generator Loss: 1.2932
# Epoch 2/2... Discriminator Loss: 1.1125... Generator Loss: 0.4670
# Epoch 2/2... Discriminator Loss: 2.4165... Generator Loss: 1.9733
# Epoch 2/2... Discriminator Loss: 0.4565... Generator Loss: 1.5017
# Epoch 2/2... Discriminator Loss: 0.2403... Generator Loss: 1.9596
# Epoch 2/2... Discriminator Loss: 1.1226... Generator Loss: 2.9967
# Epoch 2/2... Discriminator Loss: 1.0124... Generator Loss: 0.6549
# Epoch 2/2... Discriminator Loss: 0.2852... Generator Loss: 1.8880
# Epoch 2/2... Discriminator Loss: 0.1818... Generator Loss: 2.4646
# Epoch 2/2... Discriminator Loss: 0.4129... Generator Loss: 1.2835
# Epoch 2/2... Discriminator Loss: 0.3091... Generator Loss: 1.8542
# Epoch 2/2... Discriminator Loss: 1.2633... Generator Loss: 1.8787
# Epoch 2/2... Discriminator Loss: 0.4100... Generator Loss: 2.0781
# Epoch 2/2... Discriminator Loss: 0.2313... Generator Loss: 2.8968
# Epoch 2/2... Discriminator Loss: 0.7745... Generator Loss: 0.7445
# Epoch 2/2... Discriminator Loss: 0.2169... Generator Loss: 2.3115
# Epoch 2/2... Discriminator Loss: 0.2632... Generator Loss: 2.2283
# Epoch 2/2... Discriminator Loss: 1.4729... Generator Loss: 0.2919
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-af714a62406c> in <module>()
#      12 with tf.Graph().as_default():
#      13     train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
# ---> 14           mnist_dataset.shape, mnist_dataset.image_mode)
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      64         if type is None:
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#      68                 return
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3626     finally:
#    3627       if self._enforce_nesting:
# -> 3628         if self.stack[-1] is not default:
#    3629           raise AssertionError(
#    3630               "Nesting violated for default stack of %s objects"
#
# IndexError: list index out of range

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 6.0272... Generator Loss: 0.0035
# Epoch 1/1... Discriminator Loss: 4.4502... Generator Loss: 0.0221
# Epoch 1/1... Discriminator Loss: 4.0154... Generator Loss: 0.0438
# Epoch 1/1... Discriminator Loss: 2.4375... Generator Loss: 0.2032
# Epoch 1/1... Discriminator Loss: 1.7953... Generator Loss: 0.4188
# Epoch 1/1... Discriminator Loss: 1.9003... Generator Loss: 0.5138
# Epoch 1/1... Discriminator Loss: 1.4520... Generator Loss: 0.6524
# Epoch 1/1... Discriminator Loss: 1.3092... Generator Loss: 0.8559
# Epoch 1/1... Discriminator Loss: 1.3196... Generator Loss: 0.6477
# Epoch 1/1... Discriminator Loss: 1.8763... Generator Loss: 0.5149
# Epoch 1/1... Discriminator Loss: 1.7678... Generator Loss: 0.5402
# Epoch 1/1... Discriminator Loss: 1.7617... Generator Loss: 0.6018
# Epoch 1/1... Discriminator Loss: 1.5420... Generator Loss: 0.6676
# Epoch 1/1... Discriminator Loss: 1.9621... Generator Loss: 0.3612
# Epoch 1/1... Discriminator Loss: 1.7395... Generator Loss: 0.4759
# Epoch 1/1... Discriminator Loss: 1.7673... Generator Loss: 0.4767
# Epoch 1/1... Discriminator Loss: 2.0428... Generator Loss: 0.3971
# Epoch 1/1... Discriminator Loss: 1.9355... Generator Loss: 0.4351
# Epoch 1/1... Discriminator Loss: 1.8442... Generator Loss: 0.4758
# Epoch 1/1... Discriminator Loss: 1.8410... Generator Loss: 0.5269
# Epoch 1/1... Discriminator Loss: 1.7261... Generator Loss: 0.5451
# Epoch 1/1... Discriminator Loss: 1.6660... Generator Loss: 0.5510
# Epoch 1/1... Discriminator Loss: 1.6962... Generator Loss: 0.5466
# Epoch 1/1... Discriminator Loss: 1.6422... Generator Loss: 0.5415
# Epoch 1/1... Discriminator Loss: 1.5473... Generator Loss: 0.6280
# Epoch 1/1... Discriminator Loss: 1.5850... Generator Loss: 0.5783
# Epoch 1/1... Discriminator Loss: 1.6022... Generator Loss: 0.6082
# Epoch 1/1... Discriminator Loss: 1.6027... Generator Loss: 0.6071
# Epoch 1/1... Discriminator Loss: 1.5465... Generator Loss: 0.6092
# Epoch 1/1... Discriminator Loss: 1.5485... Generator Loss: 0.6294
# Epoch 1/1... Discriminator Loss: 1.6219... Generator Loss: 0.5490
# Epoch 1/1... Discriminator Loss: 1.5777... Generator Loss: 0.5876
# Epoch 1/1... Discriminator Loss: 1.4573... Generator Loss: 0.6747
# Epoch 1/1... Discriminator Loss: 1.5736... Generator Loss: 0.5775
# Epoch 1/1... Discriminator Loss: 1.5287... Generator Loss: 0.6153
# Epoch 1/1... Discriminator Loss: 1.4925... Generator Loss: 0.6663
# Epoch 1/1... Discriminator Loss: 1.5162... Generator Loss: 0.6177
# Epoch 1/1... Discriminator Loss: 1.4924... Generator Loss: 0.6244
# Epoch 1/1... Discriminator Loss: 1.4363... Generator Loss: 0.6525
# Epoch 1/1... Discriminator Loss: 1.4486... Generator Loss: 0.6631
# Epoch 1/1... Discriminator Loss: 1.4759... Generator Loss: 0.6365
# Epoch 1/1... Discriminator Loss: 1.5475... Generator Loss: 0.5804
# Epoch 1/1... Discriminator Loss: 1.4402... Generator Loss: 0.6432
# Epoch 1/1... Discriminator Loss: 1.4307... Generator Loss: 0.6995
# Epoch 1/1... Discriminator Loss: 1.4457... Generator Loss: 0.6662
# Epoch 1/1... Discriminator Loss: 1.5130... Generator Loss: 0.6267
# Epoch 1/1... Discriminator Loss: 1.4702... Generator Loss: 0.6363
# Epoch 1/1... Discriminator Loss: 1.4982... Generator Loss: 0.6305
# Epoch 1/1... Discriminator Loss: 1.4214... Generator Loss: 0.6993
# Epoch 1/1... Discriminator Loss: 1.5174... Generator Loss: 0.6012
# Epoch 1/1... Discriminator Loss: 1.4840... Generator Loss: 0.6140
# Epoch 1/1... Discriminator Loss: 1.4184... Generator Loss: 0.6702
# Epoch 1/1... Discriminator Loss: 1.4902... Generator Loss: 0.6346
# Epoch 1/1... Discriminator Loss: 1.4644... Generator Loss: 0.6641
# Epoch 1/1... Discriminator Loss: 1.4761... Generator Loss: 0.6317
# Epoch 1/1... Discriminator Loss: 1.4672... Generator Loss: 0.6257
# Epoch 1/1... Discriminator Loss: 1.5093... Generator Loss: 0.6098
# Epoch 1/1... Discriminator Loss: 1.4962... Generator Loss: 0.6003
# Epoch 1/1... Discriminator Loss: 1.4096... Generator Loss: 0.6641
# Epoch 1/1... Discriminator Loss: 1.4649... Generator Loss: 0.6603
# Epoch 1/1... Discriminator Loss: 1.4363... Generator Loss: 0.6254
# Epoch 1/1... Discriminator Loss: 1.4611... Generator Loss: 0.6544
# Epoch 1/1... Discriminator Loss: 1.4637... Generator Loss: 0.6440
# Epoch 1/1... Discriminator Loss: 1.4236... Generator Loss: 0.6601
# Epoch 1/1... Discriminator Loss: 1.4399... Generator Loss: 0.6464
# Epoch 1/1... Discriminator Loss: 1.4858... Generator Loss: 0.6134
# Epoch 1/1... Discriminator Loss: 1.4594... Generator Loss: 0.6384
# Epoch 1/1... Discriminator Loss: 1.5020... Generator Loss: 0.6215
# Epoch 1/1... Discriminator Loss: 1.4230... Generator Loss: 0.6616
# Epoch 1/1... Discriminator Loss: 1.4409... Generator Loss: 0.6571
# Epoch 1/1... Discriminator Loss: 1.4749... Generator Loss: 0.6630
# Epoch 1/1... Discriminator Loss: 1.5210... Generator Loss: 0.5973
# Epoch 1/1... Discriminator Loss: 1.4661... Generator Loss: 0.6460
# Epoch 1/1... Discriminator Loss: 1.4751... Generator Loss: 0.6337
# Epoch 1/1... Discriminator Loss: 1.4659... Generator Loss: 0.6276
# Epoch 1/1... Discriminator Loss: 1.4949... Generator Loss: 0.6256
# Epoch 1/1... Discriminator Loss: 1.4676... Generator Loss: 0.6289
# Epoch 1/1... Discriminator Loss: 1.4900... Generator Loss: 0.6298
# Epoch 1/1... Discriminator Loss: 1.4887... Generator Loss: 0.6245
# Epoch 1/1... Discriminator Loss: 1.4117... Generator Loss: 0.6810
# Epoch 1/1... Discriminator Loss: 1.5273... Generator Loss: 0.6107
# Epoch 1/1... Discriminator Loss: 1.4826... Generator Loss: 0.6286
# Epoch 1/1... Discriminator Loss: 1.4482... Generator Loss: 0.6433
# Epoch 1/1... Discriminator Loss: 1.4376... Generator Loss: 0.6527
# Epoch 1/1... Discriminator Loss: 1.4440... Generator Loss: 0.6704
# Epoch 1/1... Discriminator Loss: 1.4695... Generator Loss: 0.6348
# Epoch 1/1... Discriminator Loss: 1.4853... Generator Loss: 0.6090
# Epoch 1/1... Discriminator Loss: 1.4390... Generator Loss: 0.6409
# Epoch 1/1... Discriminator Loss: 1.4854... Generator Loss: 0.6646
# Epoch 1/1... Discriminator Loss: 1.4871... Generator Loss: 0.6250
# Epoch 1/1... Discriminator Loss: 1.4526... Generator Loss: 0.6393
# Epoch 1/1... Discriminator Loss: 1.4491... Generator Loss: 0.6505
# Epoch 1/1... Discriminator Loss: 1.4691... Generator Loss: 0.6408
# Epoch 1/1... Discriminator Loss: 1.4601... Generator Loss: 0.6419
# Epoch 1/1... Discriminator Loss: 1.4560... Generator Loss: 0.6664
# Epoch 1/1... Discriminator Loss: 1.4450... Generator Loss: 0.6356
# Epoch 1/1... Discriminator Loss: 1.4504... Generator Loss: 0.6373
# Epoch 1/1... Discriminator Loss: 1.4461... Generator Loss: 0.6673
# Epoch 1/1... Discriminator Loss: 1.4480... Generator Loss: 0.6496
# Epoch 1/1... Discriminator Loss: 1.4800... Generator Loss: 0.6326
# Epoch 1/1... Discriminator Loss: 1.4498... Generator Loss: 0.6575
# Epoch 1/1... Discriminator Loss: 1.4362... Generator Loss: 0.6548
# Epoch 1/1... Discriminator Loss: 1.4772... Generator Loss: 0.6464
# Epoch 1/1... Discriminator Loss: 1.4355... Generator Loss: 0.6515
# Epoch 1/1... Discriminator Loss: 1.4631... Generator Loss: 0.6457
# Epoch 1/1... Discriminator Loss: 1.4574... Generator Loss: 0.6474
# Epoch 1/1... Discriminator Loss: 1.4332... Generator Loss: 0.6291
# Epoch 1/1... Discriminator Loss: 1.4413... Generator Loss: 0.6666
# Epoch 1/1... Discriminator Loss: 1.4142... Generator Loss: 0.6311
# Epoch 1/1... Discriminator Loss: 1.4708... Generator Loss: 0.6460
# Epoch 1/1... Discriminator Loss: 1.4709... Generator Loss: 0.6204
# Epoch 1/1... Discriminator Loss: 1.4732... Generator Loss: 0.6455
# Epoch 1/1... Discriminator Loss: 1.4287... Generator Loss: 0.6361
# Epoch 1/1... Discriminator Loss: 1.4628... Generator Loss: 0.6250
# Epoch 1/1... Discriminator Loss: 1.4424... Generator Loss: 0.6758
# Epoch 1/1... Discriminator Loss: 1.4462... Generator Loss: 0.6586
# Epoch 1/1... Discriminator Loss: 1.4348... Generator Loss: 0.6347
# Epoch 1/1... Discriminator Loss: 1.4561... Generator Loss: 0.6574
# Epoch 1/1... Discriminator Loss: 1.4971... Generator Loss: 0.6061
# Epoch 1/1... Discriminator Loss: 1.4451... Generator Loss: 0.6435
# Epoch 1/1... Discriminator Loss: 1.4680... Generator Loss: 0.6373
# Epoch 1/1... Discriminator Loss: 1.4722... Generator Loss: 0.6345
# Epoch 1/1... Discriminator Loss: 1.4541... Generator Loss: 0.6453
# Epoch 1/1... Discriminator Loss: 1.4613... Generator Loss: 0.6342
# Epoch 1/1... Discriminator Loss: 1.4413... Generator Loss: 0.6564
# Epoch 1/1... Discriminator Loss: 1.4521... Generator Loss: 0.6242
# Epoch 1/1... Discriminator Loss: 1.4472... Generator Loss: 0.6614
# Epoch 1/1... Discriminator Loss: 1.4321... Generator Loss: 0.6438
# Epoch 1/1... Discriminator Loss: 1.4603... Generator Loss: 0.6462
# Epoch 1/1... Discriminator Loss: 1.4457... Generator Loss: 0.6368
# Epoch 1/1... Discriminator Loss: 1.4639... Generator Loss: 0.6333
# Epoch 1/1... Discriminator Loss: 1.4523... Generator Loss: 0.6269
# Epoch 1/1... Discriminator Loss: 1.4422... Generator Loss: 0.6405
# Epoch 1/1... Discriminator Loss: 1.4597... Generator Loss: 0.6408
# Epoch 1/1... Discriminator Loss: 1.4443... Generator Loss: 0.6463
# Epoch 1/1... Discriminator Loss: 1.4660... Generator Loss: 0.6191
# Epoch 1/1... Discriminator Loss: 1.4957... Generator Loss: 0.6179
# Epoch 1/1... Discriminator Loss: 1.4493... Generator Loss: 0.6439
# Epoch 1/1... Discriminator Loss: 1.4851... Generator Loss: 0.6109
# Epoch 1/1... Discriminator Loss: 1.4997... Generator Loss: 0.6197
# Epoch 1/1... Discriminator Loss: 1.4619... Generator Loss: 0.6367
# Epoch 1/1... Discriminator Loss: 1.4674... Generator Loss: 0.6380
# Epoch 1/1... Discriminator Loss: 1.4446... Generator Loss: 0.6266
# Epoch 1/1... Discriminator Loss: 1.4313... Generator Loss: 0.6551
# Epoch 1/1... Discriminator Loss: 1.4289... Generator Loss: 0.6465
# Epoch 1/1... Discriminator Loss: 1.4298... Generator Loss: 0.6856
# Epoch 1/1... Discriminator Loss: 1.4386... Generator Loss: 0.6455
# Epoch 1/1... Discriminator Loss: 1.4524... Generator Loss: 0.6274
# Epoch 1/1... Discriminator Loss: 1.4480... Generator Loss: 0.6631
# Epoch 1/1... Discriminator Loss: 1.4449... Generator Loss: 0.6590
# Epoch 1/1... Discriminator Loss: 1.4609... Generator Loss: 0.6313
# Epoch 1/1... Discriminator Loss: 1.3965... Generator Loss: 0.6757
# Epoch 1/1... Discriminator Loss: 1.4502... Generator Loss: 0.6389
# Epoch 1/1... Discriminator Loss: 1.4479... Generator Loss: 0.6378
# Epoch 1/1... Discriminator Loss: 1.4137... Generator Loss: 0.6801
# Epoch 1/1... Discriminator Loss: 1.4990... Generator Loss: 0.6207
# Epoch 1/1... Discriminator Loss: 1.4428... Generator Loss: 0.6542
# Epoch 1/1... Discriminator Loss: 1.4550... Generator Loss: 0.6413
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-3a0d7281f899> in <module>()
#      12 with tf.Graph().as_default():
#      13     train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
# ---> 14           celeba_dataset.shape, celeba_dataset.image_mode)
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      64         if type is None:
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#      68                 return
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    3626     finally:
#    3627       if self._enforce_nesting:
# -> 3628         if self.stack[-1] is not default:
#    3629           raise AssertionError(
#    3630               "Nesting violated for default stack of %s objects"
#
# IndexError: list index out of range

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
